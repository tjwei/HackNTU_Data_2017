# %% [markdown]
# 確定有 publish 的權限
#
# https://developers.facebook.com/tools/explorer

# %%
token = input()
# Out:
# EAACEdEose0cBAFCaRuuEQRTNe4OzWAOrqw4lMJuHHfCvTjJxoKmMH45yasQpaFxUSurfvet8QQSjR8jZCH7WjEpue05ge7FOZBYCv1BMtbXqt0tKtvZC5TDrZBSZCFuuABOHe3O7shQlys7DEMmyvhobuVuUENconH31IZCbZB7BnZAhY3wWpSlG

# %%
import facebook

# %%
graph = facebook.GraphAPI(token, version="2.7")

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img = zeros(shape=(1024,1024,3))
Y, X = ogrid[0:1024,0:1024]

# %%
img = zeros(shape=(1024,1024,3))
x=y=0.
for k in range(15):
    x, y = (sin(x)) - cos(y)**2 +(X-512.)/512, 2*sin(x)*cos(y)+(Y-512.0)/512;
img[:,:,0] = x**2+y**2
img[:,:,1] = 15*abs(x)
img[:,:,2] = 15*abs(y)
imshow(img/2);

# %%
imsave("foo.png", img/2)

# %%
imshow(imread('foo.png'))

# %%
graph.put_photo(image=open('foo.png', 'rb'), message='generated using python')
# Out:
# {u'id': u'10205389756778204',
#  u'post_id': u'10201382289514027_10205389756778204'}

# %%
graph.put_photo?
